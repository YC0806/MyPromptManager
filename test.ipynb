# %%
from backend.apps.core.utils.frontmatter import parse_frontmatter

# %%
content = """---
title: Prompt Regression 20251115072557
description: Regression prompt generated by automated tests
slug: prompt-regression-20251115072557
labels:
  - test-run
author: integration.tester
---

# Prompt Regression 20251115072557

This prompt was generated at 2025-11-15T07:25:57Z to verify the creation API.

"""

metadata, body = parse_frontmatter(content)
# Out:
# # Prompt Regression 20251115072557
#
# This prompt was generated at 2025-11-15T07:25:57Z to verify the creation API.

# %%
metadata
# Out:
# {}

# %%
import datetime

# %%
datetime.datetime.now(datetime.timezone.utc).isoformat()
# Out:
# '2025-11-12T14:58:29.377348+00:00'

# %%
sorted(["1","2","3",""], reverse=False)
# Out:
# ['', '1', '2', '3']
